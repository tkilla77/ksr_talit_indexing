# %%
def count_letters(filename):
    letters = {}
    with open(filename, encoding="utf-8") as data:
        for line in data:
            for letter in line.upper():
                if letter in letters:
                    letters[letter] += 1
                else:
                    letters[letter] = 1
    
    # total = sum(letters.values())
    # letters = {k: v / total for k, v in letters.items()}

    letters = dict(sorted(letters.items(), key=lambda item: item[1], reverse=True))
    return letters

# %%
wpde = count_letters('data/countries_de.csv')
bible_de = count_letters('data/Bibel_Martin_Luther_1912_utf8.txt')

# %%
import matplotlib.pyplot as plt
import string

def plot_dict(d, label):
    x = list(string.ascii_uppercase)
    total = sum(d.values())
    y = [d[key]/total for key in x]

    plt.plot(x, y, label=label)
    plt.legend()

plot_dict(wpde, "wikipedia de")
plot_dict(bible_de, "bible de")

# %%
def count_words(filename):
    words = {}
    with open(filename, encoding="utf-8") as data:
        for line in data:
            for word in line.split():
                word = word.strip(",.;:!?/=(){}[]").upper()
                if word in words:
                    words[word] += 1
                else:
                    words[word] = 1
    
    # total = sum(letters.values())
    # letters = {k: v / total for k, v in letters.items()}

    words = dict(sorted(words.items(), key=lambda item: item[1], reverse=True))
    return words

# %%
wpde_words = count_words('data/countries_de.csv')
wpde_words
# Out:
# {'DER': 59563,
#  'DIE': 54180,
#  'UND': 42867,
#  'IN': 28275,
#  'VON': 20988,
#  'DEN': 16832,
#  'IM': 16458,
#  'DES': 15992,
#  'DAS': 14923,
#  'MIT': 11372,
#  'DEM': 11001,
#  'ZU': 10516,
#  'WURDE': 8948,
#  'ALS': 8875,
#  'AUF': 8487,
#  'SICH': 7999,
#  'EINE': 7768,
#  'NACH': 6860,
#  'FÜR': 6598,
#  'EIN': 6503,
#  'AUCH': 6448,
#  'AN': 6335,
#  'WAR': 6243,
#  'IST': 5503,
#  'AUS': 5411,
#  'ES': 5244,
#  'AM': 5092,
#  'BIS': 4980,
#  'DURCH': 4798,
#  'ZUM': 4433,
#  'UNTER': 4001,
#  'WURDEN': 3904,
#  'BEI': 3786,
#  'EINER': 3642,
#  'ZUR': 3570,
#  'SIND': 3342,
#  'NICHT': 3325,
#  '%': 3286,
#  'ÜBER': 3227,
#  'WAREN': 2998,
#  'SIE': 2885,
#  'UM': 2851,
#  'ER': 2750,
#  'VOR': 2701,
#  'JAHR': 2698,
#  'EINEN': 2640,
#  'SEIT': 2571,
#  'ODER': 2512,
#  'WERDEN': 2456,
#  'VOM': 2443,
#  'WIE': 2434,
#  'EINEM': 2286,
#  '–': 2281,
#  'NUR': 2256,
#  'ABER': 2254,
#  'HATTE': 2152,
#  'DASS': 2134,
#  'ZWISCHEN': 2134,
#  'NOCH': 2132,
#  'SOWIE': 2078,
#  'GEGEN': 2078,
#  'AB': 1988,
#  'REPUBLIK': 1978,
#  'WIRD': 1962,
#  'DIESE': 1918,
#  'REGIERUNG': 1876,
#  'ETWA': 1728,
#  'JEDOCH': 1651,
#  'SO': 1630,
#  'JAHRE': 1627,
#  'LAND': 1587,
#  'DIESER': 1578,
#  'KÖNIG': 1573,
#  'WÄHREND': 1506,
#  'BEVÖLKERUNG': 1502,
#  'SEINE': 1500,
#  'DEUTSCHEN': 1485,
#  'I': 1478,
#  'TEIL': 1473,
#  'KÖNIGREICH': 1448,
#  'JAHRHUNDERT': 1428,
#  'ISBN': 1415,
#  'ZEIT': 1381,
#  'JAHREN': 1378,
#  'PROZENT': 1348,
#  'REICH': 1321,
#  'II': 1304,
#  'HAT': 1303,
#  'ERSTEN': 1302,
#  'DE': 1300,
#  'MEHR': 1265,
#  'KAM': 1260,
#  'GESCHICHTE': 1214,
#  'ALLEM': 1196,
#  'EINES': 1186,
#  'SEINER': 1185,
#  'ENDE': 1184,
#  'WIEDER': 1181,
#  'STAAT': 1161,
#  'IHRE': 1150,
#  'DAMIT': 1134,
#  'DA': 1134,
#  'FRANKREICH': 1106,
#  'KONNTE': 1103,
#  'ZWEI': 1090,
#  'LANDES': 1062,
#  'RUSSLAND': 1041,
#  'STADT': 1029,
#  'DEUTSCHLAND': 1024,
#  'SEIN': 1008,
#  'ITALIEN': 981,
#  'GEBIET': 979,
#  'GAB': 973,
#  'VERFASSUNG': 962,
#  '1': 961,
#  'BEREITS': 924,
#  'DREI': 917,
#  'HERRSCHAFT': 917,
#  'ANDEREN': 896,
#  'EUROPÄISCHEN': 883,
#  'ALLE': 867,
#  'NEUE': 864,
#  'ÖSTERREICH': 863,
#  'GIBT': 855,
#  'JAHRHUNDERTS': 855,
#  'KRIEG': 846,
#  'MILLIONEN': 825,
#  'SEINEN': 825,
#  'ERSTE': 819,
#  'FÜHRTE': 817,
#  'WEITERE': 811,
#  'HEUTE': 810,
#  'UNGARN': 809,
#  'DIES': 808,
#  'POLEN': 799,
#  'ZWEITEN': 794,
#  'OKTOBER': 793,
#  'HABEN': 792,
#  'KARL': 791,
#  '': 787,
#  'HATTEN': 784,
#  'SPÄTER': 780,
#  'NOVEMBER': 768,
#  'DEUTSCHE': 762,
#  'ERST': 757,
#  'STAATEN': 754,
#  'GROSSE': 753,
#  'VIELE': 749,
#  'GROSSEN': 746,
#  'RUND': 746,
#  'JANUAR': 742,
#  'KEINE': 735,
#  'NEUEN': 729,
#  'PARTEI': 728,
#  'TRUPPEN': 728,
#  'DEZEMBER': 724,
#  'MAN': 723,
#  'DEREN': 723,
#  'MÄRZ': 722,
#  'KAISER': 717,
#  'JUNI': 715,
#  'MAI': 697,
#  'UKRAINE': 696,
#  'WAS': 694,
#  'IHRER': 693,
#  'ALLERDINGS': 693,
#  'SEHR': 680,
#  'EINWOHNER': 678,
#  'NEBEN': 676,
#  'ARMEE': 675,
#  'DABEI': 673,
#  'STAND': 668,
#  'A': 667,
#  'POLITISCHE': 664,
#  'SCHWEIZ': 664,
#  'GEBIETE': 663,
#  '20': 659,
#  'AUGUST': 658,
#  'RUSSISCHEN': 654,
#  'V': 652,
#  'DESSEN': 650,
#  '19': 648,
#  'OF': 644,
#  'SEINEM': 640,
#  '2': 639,
#  'INSBESONDERE': 638,
#  'IMMER': 637,
#  'BEIDEN': 633,
#  'UNION': 632,
#  '15': 626,
#  'KIRCHE': 626,
#  'WORDEN': 624,
#  'BLIEB': 622,
#  'IHREN': 620,
#  'THE': 620,
#  'BZW': 618,
#  'JULI': 610,
#  'SEPTEMBER': 604,
#  'EINIGE': 603,
#  'III': 596,
#  'FRIEDRICH': 596,
#  'SERBIEN': 594,
#  'APRIL': 590,
#  'FRANZÖSISCHEN': 589,
#  'PARLAMENT': 588,
#  'STÄDTE': 586,
#  'DENEN': 585,
#  'AUFGRUND': 584,
#  'NUN': 584,
#  'HAUPTSTADT': 577,
#  'DAZU': 571,
#  'OHNE': 567,
#  'INS': 566,
#  'ZUNÄCHST': 566,
#  '18': 563,
#  'POLITIK': 563,
#  'HERZOGTUM': 562,
#  'SCHON': 559,
#  'DIESES': 558,
#  'REICHES': 556,
#  'FEBRUAR': 554,
#  'INSGESAMT': 553,
#  'SOWJETUNION': 553,
#  'POLITISCHEN': 553,
#  'ZURÜCK': 550,
#  '1918': 545,
#  'VIER': 544,
#  'LAG': 543,
#  'PREUSSEN': 543,
#  'MACHT': 541,
#  'BESTAND': 538,
#  'GEGENÜBER': 535,
#  'SOLLTE': 530,
#  'DIESEM': 529,
#  'IHM': 527,
#  'LITERATUR': 523,
#  'SIEHE': 520,
#  'STARK': 520,
#  'EBENFALLS': 512,
#  '3': 512,
#  'FAST': 510,
#  '2020': 507,
#  'SOHN': 505,
#  'RUMÄNIEN': 504,
#  'MENSCHEN': 502,
#  'SELBST': 501,
#  'ZUSAMMEN': 501,
#  'NACHDEM': 499,
#  'SLOWAKEI': 499,
#  'GRÖSSTE': 497,
#  'TOD': 496,
#  'DORT': 494,
#  'UNABHÄNGIGKEIT': 492,
#  'TRAT': 492,
#  'EUROPA': 488,
#  'WILHELM': 488,
#  'DAVON': 486,
#  '14': 485,
#  'BEGANN': 484,
#  'HEUTIGEN': 484,
#  'FÜRSTENTUM': 484,
#  'WEITER': 484,
#  'SONDERN': 483,
#  'DANN': 483,
#  'SÜDEN': 482,
#  'KONNTEN': 482,
#  'ANDERE': 478,
#  'BESONDERS': 478,
#  'WELTKRIEG': 477,
#  'RÖMISCHEN': 477,
#  'MEISTEN': 474,
#  'ANTEIL': 474,
#  '16': 470,
#  'JUDEN': 469,
#  '13': 468,
#  'GING': 468,
#  '10': 467,
#  'MUSSTE': 467,
#  'NORDEN': 466,
#  'EURO': 466,
#  'WEGEN': 465,
#  'LETZTEN': 465,
#  'LIEGT': 463,
#  'ZUDEM': 463,
#  '2016': 463,
#  'SCHLIESSLICH': 463,
#  'IHR': 462,
#  'WIRTSCHAFT': 460,
#  'ANDEREM': 457,
#  'GRIECHENLAND': 456,
#  'ENTWICKLUNG': 454,
#  'LÄNDER': 453,
#  'GRÖSSTEN': 453,
#  'LÄNDERN': 451,
#  'STATT': 451,
#  '17': 451,
#  'PARTEIEN': 450,
#  '2017': 447,
#  'ITALIENISCHEN': 442,
#  'INNERHALB': 442,
#  'TEILE': 441,
#  'NAHM': 440,
#  'RUSSISCHE': 440,
#  'EINFLUSS': 435,
#  'OSMANISCHEN': 434,
#  'SPRACHE': 434,
#  'VERTRAG': 434,
#  'SCHLACHT': 434,
#  'REGION': 433,
#  '2008': 433,
#  'DDR': 429,
#  'ZWAR': 428,
#  'LEBEN': 428,
#  'PRO': 428,
#  '2010': 427,
#  '2014': 426,
#  'ERHIELT': 426,
#  'GEWÄHLT': 424,
#  'OSTEN': 423,
#  'WOBEI': 423,
#  'CHR': 423,
#  'HRSG': 421,
#  'DIESEN': 420,
#  '12': 419,
#  'MEHRERE': 417,
#  'INSEL': 415,
#  '5': 413,
#  'BEDEUTUNG': 413,
#  '2015': 412,
#  'U': 412,
#  'VERWALTUNG': 410,
#  '2011': 409,
#  'GEGRÜNDET': 406,
#  'BETRUG': 406,
#  'KOSOVO': 404,
#  'KULTUR': 403,
#  'KM': 402,
#  'GEMEINDEN': 401,
#  'ZAHLREICHE': 399,
#  'KAMEN': 399,
#  'ROLLE': 399,
#  'TSCHECHOSLOWAKEI': 399,
#  'BERLIN': 398,
#  'LUDWIG': 397,
#  'BEIM': 396,
#  'WESTEN': 394,
#  'ANFANG': 393,
#  'AMT': 393,
#  'RECHT': 391,
#  'SETZTE': 391,
#  'MONARCHIE': 391,
#  'BEZIEHUNGEN': 390,
#  'BULGARIEN': 388,
#  'WO': 386,
#  '4': 384,
#  'PORTUGAL': 383,
#  '2021': 382,
#  'REGIONEN': 381,
#  '9': 381,
#  'FÜNF': 380,
#  'BEZEICHNET': 380,
#  'ZAHL': 379,
#  'HIER': 378,
#  'STAATES': 378,
#  'WELT': 378,
#  '30': 377,
#  '6': 377,
#  'GILT': 376,
#  'GELANG': 376,
#  'MEHRHEIT': 375,
#  'LIESS': 374,
#  '2009': 373,
#  'PERSONEN': 372,
#  'FRANZÖSISCHE': 372,
#  '2022': 372,
#  'GRÜNDUNG': 372,
#  'SPANIEN': 370,
#  'KANN': 369,
#  'UNTERSTÜTZUNG': 369,
#  'NAMEN': 368,
#  '1945': 367,
#  'GRENZE': 366,
#  'ALLER': 366,
#  '2012': 366,
#  'BADEN': 366,
#  'WÜRTTEMBERG': 364,
#  '2019': 363,
#  'NEU': 363,
#  'INTERNATIONALEN': 362,
#  '2004': 362,
#  'BEGINN': 362,
#  'BRANDENBURG': 359,
#  'SOWOHL': 358,
#  'S': 357,
#  '2007': 356,
#  'KÖNNEN': 356,
#  'POLNISCHEN': 356,
#  'M': 354,
#  'CA': 354,
#  'PLATZ': 353,
#  'TÜRKEI': 352,
#  'WELCHE': 350,
#  'B': 350,
#  '25': 349,
#  '2005': 349,
#  'REVOLUTION': 349,
#  'BAND': 348,
#  'MITTE': 348,
#  'EUROPÄISCHE': 348,
#  'PRÄSIDENT': 348,
#  'SCHWEDEN': 348,
#  'GEHÖREN': 347,
#  'FOLGE': 346,
#  'KRONE': 346,
#  'IV': 346,
#  'SIZILIEN': 346,
#  'EU': 345,
#  'LUXEMBURG': 344,
#  'TEILWEISE': 343,
#  'IHNEN': 343,
#  '7': 342,
#  'HERZOG': 342,
#  'GRAFSCHAFT': 342,
#  'HÄLFTE': 341,
#  'GROSSBRITANNIEN': 340,
#  '2006': 339,
#  'WICHTIGE': 338,
#  'JUGOSLAWIEN': 338,
#  'VEREINIGTEN': 337,
#  'ALLEN': 336,
#  'ENTSTAND': 336,
#  'INSELN': 335,
#  'ALBANIEN': 335,
#  'SEINES': 335,
#  '11': 334,
#  'DAHER': 333,
#  'FRAUEN': 332,
#  '2018': 332,
#  'BEKANNT': 331,
#  'MONTENEGRO': 330,
#  '21': 329,
#  'HERRSCHER': 329,
#  'SCHLOSS': 328,
#  'LANGE': 327,
#  'WEITEREN': 327,
#  'TROTZ': 326,
#  'RAHMEN': 325,
#  'FÜRSTEN': 325,
#  'DOCH': 324,
#  'WENN': 324,
#  'JOHANN': 324,
#  'ERSTMALS': 322,
#  'SEITE': 322,
#  'WAHL': 320,
#  'GENANNT': 320,
#  'INTERNATIONALE': 318,
#  '8': 316,
#  'MALTA': 316,
#  'AUSSERDEM': 315,
#  'DARUNTER': 314,
#  'STÄDTEN': 314,
#  'GEPRÄGT': 314,
#  'FRIEDEN': 314,
#  'LAGE': 313,
#  'TITEL': 313,
#  'WEITERHIN': 312,
#  'PROVINZ': 312,
#  'EUROPAS': 311,
#  'LAUT': 311,
#  'BESTEHT': 311,
#  'NORWEGEN': 310,
#  'EIGENEN': 309,
#  'MILLIARDEN': 308,
#  'Z': 308,
#  'ZUVOR': 308,
#  'LA': 307,
#  'KROATIEN': 305,
#  'EIGENE': 303,
#  'TERRITORIUM': 303,
#  'OBWOHL': 302,
#  'GANZ': 300,
#  'NACHFOLGER': 300,
#  'OFT': 300,
#  'ALTEN': 300,
#  'ROM': 300,
#  'MEIST': 299,
#  'WIRTSCHAFTLICHE': 299,
#  'ITALIENISCHE': 299,
#  'BEIDE': 298,
#  'FÜHRUNG': 298,
#  'IHN': 298,
#  'KÖNIGREICHS': 297,
#  '2013': 296,
#  'HEILIGEN': 296,
#  'PROVINZEN': 293,
#  'FAND': 291,
#  'DARAUF': 290,
#  'WEITGEHEND': 289,
#  'STAATLICHEN': 289,
#  'LANDWIRTSCHAFT': 289,
#  'PETER': 289,
#  'MITGLIED': 288,
#  'ERREICHTE': 288,
#  'PRÄSIDENTEN': 288,
#  'MITGLIEDER': 287,
#  '1920': 287,
#  'PAPST': 287,
#  'GEBIETEN': 286,
#  'DANACH': 286,
#  'UMFASSTE': 286,
#  'ERSTER': 286,
#  'ERNEUT': 286,
#  'SOLDATEN': 286,
#  'STAATLICHE': 285,
#  'MARK': 285,
#  'WENIGER': 284,
#  'KÖNIGS': 284,
#  '28': 283,
#  'WAHLEN': 283,
#  'WICHTIGSTEN': 283,
#  'FOLGENDEN': 282,
#  'MÜNCHEN': 282,
#  'GROSSHERZOGTUM': 282,
#  'BEISPIEL': 279,
#  'ERHALTEN': 279,
#  '2000': 279,
#  'GRENZEN': 278,
#  'ZUGE': 278,
#  'ZWEITE': 278,
#  'KRAFT': 278,
#  'VERSUCHTE': 277,
#  'NAPOLEON': 277,
#  'LITAUEN': 277,
#  'ENTSTANDEN': 276,
#  'OSMANISCHE': 276,
#  '"': 274,
#  'FIEL': 273,
#  'STUTTGART': 273,
#  'GEHÖRT': 272,
#  'UNTERNEHMEN': 272,
#  'VIELEN': 271,
#  'BAYERN': 271,
#  'KONTROLLE': 271,
#  'DAFÜR': 270,
#  'VENEDIG': 270,
#  'NATIONALE': 270,
#  '24': 269,
#  'OFFIZIELL': 269,
#  'BILDUNG': 269,
#  'ARAGONIEN': 269,
#  'AND': 269,
#  'UNIVERSITÄT': 268,
#  'FOLGTE': 268,
#  'SCHWEIZER': 268,
#  'WIEN': 268,
#  'DEUTLICH': 267,
#  'KILOMETER': 266,
#  'TAG': 266,
#  'MANN': 266,
#  '1919': 266,
#  'WEIT': 265,
#  'ART': 265,
#  'LISTE': 264,
#  'STELLTE': 264,
#  '23': 263,
#  'SECHS': 262,
#  'HOHEN': 262,
#  'DADURCH': 261,
#  'GESELLSCHAFT': 261,
#  'VERSCHIEDENEN': 260,
#  'GESETZ': 260,
#  'JEWEILS': 260,
#  'EHEMALIGEN': 259,
#  'FRANZ': 259,
#  'ZENTRUM': 258,
#  'KURZ': 258,
#  'JE': 257,
#  '1990': 257,
#  'BILDETE': 257,
#  'LIECHTENSTEIN': 257,
#  'ERKLÄRTE': 256,
#  'SERBISCHEN': 256,
#  'BIP': 255,
#  'INDUSTRIE': 255,
#  'FINNLAND': 255,
#  'SPRACHEN': 254,
#  'IHREM': 254,
#  'RAT': 254,
#  'BEZEICHNUNG': 254,
#  'WEIL': 254,
#  'PARIS': 253,
#  'SAN': 253,
#  'ZUNEHMEND': 253,
#  'GEHÖRTE': 252,
#  'ERFOLGTE': 252,
#  '1989': 251,
#  'FÜHRTEN': 251,
#  'STARB': 251,
#  'KM²': 251,
#  'MOLDAU': 251,
#  'UNGARISCHEN': 250,
#  'EINZELNACHWEISE': 249,
#  'WIRTSCHAFTLICHEN': 249,
#  'SOMIT': 248,
#  'BLIEBEN': 248,
#  '22': 247,
#  'NIEDERLAGE': 247,
#  'FRANKREICHS': 247,
#  'SEI': 246,
#  'VERGLEICH': 246,
#  'ENTWICKELTE': 246,
#  'EINIGEN': 245,
#  'DARAUFHIN': 244,
#  'BEDEUTENDE': 243,
#  'GEWANN': 243,
#  'DANZIG': 243,
#  'VERTRETER': 242,
#  'SYSTEM': 242,
#  'WIENER': 242,
#  '2023': 241,
#  'WELTWEIT': 241,
#  'EHER': 241,
#  'BOSNIEN': 241,
#  '2001': 240,
#  '2003': 240,
#  'GLEICHZEITIG': 239,
#  'ANZAHL': 239,
#  'BYZANTINISCHEN': 239,
#  'EINGEFÜHRT': 239,
#  'SOLL': 238,
#  'SOGAR': 238,
#  'DANEBEN': 238,
#  'ZIEL': 238,
#  'RUSSLANDS': 238,
#  'AUSLAND': 237,
#  'HILFE': 237,
#  'INTERNATIONAL': 237,
#  'MINDERHEIT': 236,
#  'HINAUS': 236,
#  'HOHE': 235,
#  '2002': 235,
#  'EBENSO': 235,
#  'DEUTSCH': 235,
#  'EROBERUNG': 235,
#  'KLEINE': 234,
#  '1991': 234,
#  'MUSSTEN': 234,
#  'US-DOLLAR': 234,
#  'KÖNIGE': 234,
#  'BEISPIELSWEISE': 233,
#  'GESAMTEN': 233,
#  'SITZ': 233,
#  'POLNISCHE': 233,
#  'FERDINAND': 233,
#  'MRD': 232,
#  'GRIECHISCHEN': 231,
#  'ALSO': 231,
#  'GEHÖRTEN': 231,
#  '26': 231,
#  'MINISTERPRÄSIDENT': 231,
#  'WIDERSTAND': 231,
#  '29': 231,
#  'SLOWAKISCHE': 231,
#  'EINWOHNERN': 230,
#  'SERBEN': 230,
#  'BESETZT': 230,
#  'ISLAND': 230,
#  'AUFLAGE': 230,
#  'KURFÜRST': 230,
#  'STIEG': 229,
#  'ÖSTERREICHISCHEN': 229,
#  'WEBLINKS': 229,
#  'HAUPTSÄCHLICH': 228,
#  'MACHTE': 227,
#  'BILDETEN': 227,
#  'BELARUS': 227,
#  'VERLAG': 226,
#  'MEER': 226,
#  'FÜRST': 226,
#  'VERLOR': 226,
#  'BÖHMEN': 226,
#  'SACHSEN': 226,
#  'KNAPP': 225,
#  'RECHTE': 225,
#  'DAMALS': 224,
#  '1944': 224,
#  'ANERKANNT': 222,
#  'STANDEN': 222,
#  'BEREICH': 222,
#  'GESAMTE': 222,
#  'REFORMEN': 221,
#  'SPANISCHEN': 221,
#  'HEINRICH': 221,
#  'ÜBERNAHM': 221,
#  'ENGLAND': 221,
#  'VERTRETEN': 220,
#  'HAUS': 220,
#  'ÖFFENTLICHEN': 219,
#  'LEDIGLICH': 219,
#  'EINFÜHRUNG': 219,
#  'SLOWAKISCHEN': 219,
#  '27': 218,
#  'KEIN': 218,
#  'ÜBERWIEGEND': 218,
#  'SAH': 218,
#  'GENERAL': 217,
#  'NATIONALEN': 216,
#  'LETZTE': 216,
#  'FINDEN': 216,
#  'IRLAND': 214,
#  'RELATIV': 213,
#  'SIEBEN': 213,
#  'TEILEN': 213,
#  'VERLOREN': 212,
#  'ENGLISCH': 212,
#  'ALEXANDER': 212,
#  '40': 211,
#  'EINZIGE': 211,
#  'BUND': 211,
#  'LEBTEN': 211,
#  'SOGENANNTEN': 211,
#  'BESTEHEN': 211,
#  'VERSCHIEDENE': 210,
#  'BETRÄGT': 210,
#  'KATHOLISCHEN': 210,
#  'FLÄCHE': 209,
#  'KAUM': 209,
#  'STATUS': 209,
#  '1000': 209,
#  'DARÜBER': 208,
#  'KRIEGES': 208,
#  'MICHAEL': 207,
#  'ITALIENS': 206,
#  'FORM': 206,
#  'DI': 206,
#  'WOLLTE': 205,
#  '31': 205,
#  'GALT': 204,
#  '1999': 204,
#  'WENIG': 204,
#  'HÄUFIG': 202,
#  'RÖMISCHE': 202,
#  'KURFÜRSTEN': 202,
#  'DAGEGEN': 201,
#  'MÄNNER': 201,
#  '1992': 201,
#  'OSMANEN': 201,
#  'STIMMEN': 201,
#  'SOLLTEN': 201,
#  'BESITZ': 200,
#  'MINDERHEITEN': 199,
#  'NEAPEL': 199,
#  'MILITÄR': 199,
#  'MOSKAU': 199,
#  '°C': 198,
#  'HÖHE': 198,
#  'KLEINEN': 198,
#  'STREITKRÄFTE': 198,
#  'GUT': 198,
#  'MILITÄRISCHEN': 198,
#  'AUFSTAND': 197,
#  'ZEHN': 197,
#  '1939': 196,
#  'UNGARISCHE': 196,
#  'BILDEN': 195,
#  'GROSSER': 195,
#  'DRITTEL': 195,
#  'HANDEL': 195,
#  'PHILIPP': 195,
#  'BRUDER': 195,
#  'GROSSTEIL': 194,
#  'NATIONEN': 194,
#  'BELGIEN': 194,
#  'GEWESEN': 194,
#  'FANDEN': 194,
#  'PRESS': 194,
#  'GEGENSATZ': 193,
#  'BALD': 193,
#  'BRACHTE': 192,
#  'USA': 192,
#  'ZAHLREICHEN': 192,
#  '1946': 192,
#  'JAHRES': 191,
#  'EBENE': 191,
#  'BUNDESREPUBLIK': 191,
#  'REICHS': 190,
#  'MAL': 190,
#  'NAME': 190,
#  'DRUCK': 190,
#  '100': 190,
#  'UNABHÄNGIG': 189,
#  'HESSEN': 189,
#  'QUELLEN': 188,
#  'WENIGE': 188,
#  'VOLKSREPUBLIK': 188,
#  'MINISTERPRÄSIDENTEN': 188,
#  'HERZEGOWINA': 188,
#  'HALBINSEL': 188,
#  'RUS': 188,
#  'OPPOSITION': 188,
#  '1815': 188,
#  'HÖCHSTE': 187,
#  'WESTLICHEN': 187,
#  'HINGEGEN': 186,
#  'ORGANISATION': 186,
#  'DIREKT': 186,
#  'JÄHRLICH': 186,
#  '1806': 186,
#  '1941': 186,
#  'ENDETE': 186,
#  'LANDTAG': 186,
#  'E': 185,
#  'GRUPPE': 185,
#  'ZÄHLEN': 185,
#  'POLENS': 185,
#  'GRÖSSEREN': 184,
#  'SOMMER': 184,
#  'SELBEN': 184,
#  'BÜRGER': 184,
#  'ENDGÜLTIG': 184,
#  'VERWENDET': 184,
#  'SCHUTZ': 183,
#  'LIEGEN': 182,
#  'MUSIK': 182,
#  'UNIVERSITY': 182,
#  '50': 182,
#  '1848': 182,
#  'ZUGLEICH': 182,
#  'KASACHSTAN': 181,
#  'INFOLGE': 181,
#  'MEHREREN': 180,
#  'BISHER': 180,
#  'HEER': 180,
#  'DENNOCH': 179,
#  'WERT': 179,
#  'HISTORISCHEN': 179,
#  'NIEDERLANDE': 179,
#  'FAMILIE': 178,
#  'HEUTIGE': 178,
#  'BEFINDET': 178,
#  'MILITÄRISCHE': 178,
#  'NATO': 177,
#  'GEMEINDE': 177,
#  'SIEG': 177,
#  'KONFLIKT': 177,
#  'LINIE': 177,
#  'DANZIGER': 177,
#  'SCHULEN': 176,
#  'ORGANISIERT': 176,
#  'ÖFFENTLICHE': 176,
#  'FRANZÖSISCH': 175,
#  'BESETZUNG': 175,
#  'FREIEN': 175,
#  'BAU': 175,
#  'TOURISMUS': 175,
#  'GESETZE': 175,
#  'TERRITORIEN': 175,
#  'DEUTSCHER': 175,
#  'SEITEN': 174,
#  '1995': 174,
#  'GRÖSSERE': 174,
#  'BEFINDEN': 173,
#  'AUSSENPOLITIK': 173,
#  'MARINO': 173,
#  'PREUSSISCHEN': 173,
#  'VERBUNDEN': 172,
#  'GEMÄSS': 172,
#  'MIO': 172,
#  'ABKOMMEN': 172,
#  '1938': 172,
#  'ZUSAMMENARBEIT': 171,
#  'REIHE': 171,
#  'SPIELEN': 171,
#  'MITTELALTER': 171,
#  'VEREINTEN': 170,
#  'SERBISCHE': 170,
#  'FRANKFURT': 170,
#  'UKRAINISCHE': 170,
#  'HIN': 170,
#  'AUTONOMIE': 170,
#  'POLITISCH': 169,
#  'DAR': 169,
#  'ZOG': 169,
#  'NATIONALVERSAMMLUNG': 169,
#  'OFFIZIELLE': 168,
#  'STARKE': 168,
#  'KIRCHEN': 168,
#  'FRANKEN': 168,
#  'OTTO': 168,
#  'BRITISCHEN': 168,
#  'TSCHECHOSLOWAKISCHE': 168,
#  'BERG': 167,
#  'KOMMUNISTISCHEN': 167,
#  'EINZELNEN': 167,
#  'ESTLAND': 167,
#  'VEREINIGTE': 166,
#  'KLIMA': 166,
#  'KOMMEN': 166,
#  'TRADITION': 166,
#  'FRÜHEN': 166,
#  'VOLK': 166,
#  'KINDER': 165,
#  'DRITTEN': 165,
#  'AUFLÖSUNG': 165,
#  'UNTERSTÜTZT': 165,
#  'ADEL': 165,
#  'SLOWENIEN': 165,
#  'GROSSHERZOG': 165,
#  'ACHT': 164,
#  'SOZIALISTISCHE': 164,
#  'SPÄTEREN': 164,
#  'TAGE': 164,
#  'VERFÜGT': 163,
#  'GINGEN': 163,
#  'SITUATION': 163,
#  'AUFGELÖST': 163,
#  'WIEDERUM': 163,
#  'MACHEN': 163,
#  'LETTLAND': 163,
#  'FLORENZ': 163,
#  'STELLEN': 162,
#  'SÜDLICHEN': 162,
#  'DYNASTIE': 162,
#  'KONSTANTINOPEL': 162,
#  'GLEICHEN': 161,
#  'FÜRSTENTUMS': 161,
#  'SOGENANNTE': 161,
#  'ALTE': 161,
#  'HÖCHSTEN': 160,
#  'JÜDISCHE': 160,
#  'SOZIALISTISCHEN': 160,
#  'JOHANNES': 160,
#  'DENN': 159,
#  'LASSEN': 159,
#  'REGIERTE': 159,
#  'KAMPF': 159,
#  'FINDET': 159,
#  'MÖGLICH': 159,
#  'TEILS': 159,
#  'STELLUNG': 159,
#  'ÖSTERREICH-UNGARN': 159,
#  'TÜRKISCHEN': 159,
#  'VOLLSTÄNDIG': 158,
#  'ANDORRA': 158,
#  'VERHÄLTNIS': 158,
#  'VORBILD': 158,
#  'ERNANNT': 157,
#  'NEUER': 157,
#  'VERHANDLUNGEN': 157,
#  'LONDON': 157,
#  'URSPRÜNGLICH': 156,
#  '60': 156,
#  'INSTITUTIONEN': 156,
#  'ERREICHEN': 156,
#  'BETRIEB': 156,
#  'WELTKRIEGS': 156,
#  'FRAGE': 156,
#  'JOSEPH': 156,
#  'PREMIERMINISTER': 156,
#  'STAATSGEBIET': 155,
#  'AUSSERHALB': 155,
#  'ABGEORDNETEN': 155,
#  'KUNST': 155,
#  'HISTORISCHE': 155,
#  'DONAU': 155,
#  'TSCHECHOSLOWAKISCHEN': 155,
#  'HINZU': 154,
#  'BETRIEBEN': 154,
#  '1993': 154,
#  'INDEM': 154,
#  'LIBERALEN': 154,
#  'MÄHREN': 154,
#  'BEKANNTE': 153,
#  'GEMEINSAM': 153,
#  'PRAG': 153,
#  'NIE': 153,
#  'GEBILDET': 152,
#  'AUSNAHME': 152,
#  'ZUSTIMMUNG': 152,
#  'RICHTUNG': 151,
#  'BÜNDNIS': 151,
#  'WICHTIGSTE': 151,
#  'DESHALB': 151,
#  'KÜSTE': 150,
#  'LANG': 150,
#  'RELIGION': 150,
#  'VEREINIGUNG': 150,
#  'ÖSTERREICHISCHE': 150,
#  'STELLE': 150,
#  'VERSAMMLUNG': 150,
#  'VOLKSZÄHLUNG': 149,
#  'BESETZTEN': 149,
#  'WAHLRECHT': 149,
#  'INNEREN': 149,
#  'WAPPEN': 149,
#  '1940': 149,
#  'GRIECHEN': 148,
#  'GANZEN': 148,
#  'NAHMEN': 148,
#  'MONACO': 148,
#  ...}

# %%
biblede_words = count_words('data/Bibel_Martin_Luther_1912_utf8.txt')
biblede_words
# Out:
# {'UND': 46295,
#  'DER': 18719,
#  'DIE': 16552,
#  'A': 13882,
#  '-': 11606,
#  'ZU': 10141,
#  'SIE': 9808,
#  'DEN': 8743,
#  'DAS': 8648,
#  'ER': 8588,
#  'DASS': 8107,
#  'ICH': 7936,
#  'NICHT': 7595,
#  'IN': 7057,
#  '1': 7025,
#  'DES': 7022,
#  'DEM': 6931,
#  'IST': 6443,
#  'ABER': 6014,
#  'VON': 5984,
#  '2': 5671,
#  'MIT': 5471,
#  'AUF': 5458,
#  'DA': 5442,
#  'DU': 5282,
#  'DENN': 5204,
#  'EIN': 4932,
#  'IHR': 4695,
#  'HERR': 4515,
#  'SO': 4419,
#  'ES': 4384,
#  'AN': 3913,
#  'HERRN': 3784,
#  'SPRACH': 3776,
#  'IHM': 3471,
#  'WIRD': 3380,
#  'WIE': 3377,
#  'SICH': 3303,
#  'SEIN': 3180,
#  'EUCH': 2987,
#  'GOTT': 2914,
#  'HAT': 2913,
#  'VOR': 2882,
#  'MOSE': 2860,
#  'IHN': 2803,
#  'WERDEN': 2559,
#  'WAR': 2509,
#  'MIR': 2427,
#  'AUS': 2398,
#  'AUCH': 2397,
#  'WILL': 2382,
#  'WAS': 2340,
#  'SIND': 2282,
#  'IHNEN': 2271,
#  'ÜBER': 2264,
#  'ALLE': 2238,
#  'DIR': 2224,
#  'SEINE': 2179,
#  'SOLL': 2100,
#  'IM': 2077,
#  'KÖNIG': 2077,
#  'MICH': 2007,
#  'B': 1980,
#  'ISRAEL': 1911,
#  'DICH': 1884,
#  'NACH': 1854,
#  'WIR': 1844,
#  'VOLK': 1823,
#  'ZUM': 1792,
#  'UNTER': 1765,
#  'SOHN': 1759,
#  'KINDER': 1728,
#  'EINEN': 1710,
#  '4': 1667,
#  'HABE': 1555,
#  'MEIN': 1555,
#  'UNS': 1520,
#  'WENN': 1507,
#  'HABEN': 1504,
#  'IHRE': 1499,
#  'EINE': 1483,
#  '5': 1482,
#  'HATTE': 1428,
#  'UM': 1408,
#  'SEINEN': 1379,
#  'DEINE': 1359,
#  'ALSO': 1352,
#  'PSALM': 1336,
#  'SIEHE': 1312,
#  'NUN': 1300,
#  'MEINE': 1295,
#  'WAREN': 1284,
#  'DEIN': 1279,
#  'NOCH': 1248,
#  '3': 1239,
#  'BEI': 1199,
#  'SEINEM': 1196,
#  'MAN': 1177,
#  'DURCH': 1165,
#  'GOTTES': 1164,
#  'WER': 1160,
#  'SPRICHT': 1140,
#  'DARUM': 1138,
#  'BIS': 1138,
#  'ALLES': 1133,
#  'WARD': 1087,
#  'AM': 1083,
#  'HAND': 1058,
#  'SEI': 1047,
#  'SONDERN': 1042,
#  'SOLLEN': 982,
#  'SEINER': 981,
#  'HAST': 960,
#  'ODER': 958,
#  'IHREN': 941,
#  'SOLLST': 927,
#  'WIDER': 912,
#  'TUN': 910,
#  'LAND': 877,
#  'GEN': 874,
#  'ZEIT': 871,
#  'VOM': 866,
#  'BIN': 842,
#  'FÜR': 837,
#  'HAUSE': 830,
#  'HAUS': 827,
#  'HIN': 822,
#  'ALLEN': 819,
#  'STADT': 819,
#  'ZUR': 818,
#  'DAVID': 806,
#  'DOCH': 779,
#  'JERUSALEM': 779,
#  'KAM': 770,
#  'VATER': 758,
#  'DEINEN': 750,
#  'LANDE': 745,
#  'SPRACHEN': 733,
#  'MANN': 730,
#  'SAGEN': 729,
#  'ALS': 724,
#  'KOMMEN': 710,
#  'EINEM': 708,
#  'TAGE': 706,
#  'GING': 687,
#  'MATTHÄUS': 685,
#  'MEHR': 675,
#  'WIEDER': 663,
#  'DEINEM': 662,
#  'WORT': 661,
#  'JESAJA': 657,
#  'KÖNIGE': 653,
#  'ANDERN': 648,
#  'ISRAELS': 632,
#  'MENSCHEN': 622,
#  'DIESE': 620,
#  'NAMEN': 609,
#  'HIMMEL': 606,
#  'JESUS': 606,
#  'IHRER': 597,
#  'GEBEN': 590,
#  'LEBEN': 578,
#  'PRIESTER': 577,
#  'SOLLT': 573,
#  'KOMMT': 573,
#  'MEINEM': 572,
#  'MEINEN': 568,
#  'KEIN': 567,
#  'KÖNIGS': 566,
#  'GETAN': 562,
#  'KINDERN': 562,
#  'GEGEN': 559,
#  'JUDA': 554,
#  'WERDE': 553,
#  'MACHEN': 553,
#  'JOHANNES': 552,
#  'WASSER': 552,
#  'LASSEN': 552,
#  'WO': 551,
#  'ZWEI': 549,
#  'EINER': 548,
#  'DEINER': 542,
#  'BIST': 541,
#  'GEGEBEN': 539,
#  'ERDE': 532,
#  'SAH': 529,
#  'AUGEN': 527,
#  'DIES': 525,
#  'NICHTS': 524,
#  'EURE': 520,
#  'HER': 516,
#  'VIEL': 511,
#  'WOHL': 510,
#  'WILLEN': 505,
#  '\x96': 502,
#  'GEHEN': 498,
#  'SEID': 492,
#  'HEIDEN': 492,
#  'LUKAS': 491,
#  'TAG': 483,
#  'WEIB': 482,
#  'HERZ': 482,
#  'SEINES': 480,
#  'JEREMIA': 457,
#  'SOHNES': 457,
#  'KAMEN': 455,
#  'MACHTE': 454,
#  'LIESS': 452,
#  'SEELE': 451,
#  'GEIST': 450,
#  'MACHT': 448,
#  'IHREM': 446,
#  'SOLCHES': 446,
#  'HABT': 446,
#  'DARIN': 443,
#  'SAMUEL': 443,
#  'DASELBST': 441,
#  'NAHM': 440,
#  'NIEMAND': 438,
#  'GEMACHT': 436,
#  'LASS': 432,
#  'JAHRE': 426,
#  'HATTEN': 424,
#  'SAGE': 422,
#  'MÄNNER': 419,
#  'FEUER': 418,
#  'GESAGT': 417,
#  'ANTWORTETE': 417,
#  'SEHEN': 410,
#  'HÄNDE': 404,
#  'VGL': 403,
#  'KORINTHER': 398,
#  'GANZE': 395,
#  'ESSEN': 395,
#  'HEILIGEN': 394,
#  'WURDEN': 392,
#  'EUER': 392,
#  'KNECHT': 389,
#  'DENEN': 388,
#  'WEG': 387,
#  'WIRST': 386,
#  'INS': 386,
#  'TUT': 383,
#  'DEINES': 381,
#  'RECHT': 378,
#  'RÖMER': 377,
#  'TAT': 376,
#  'SCHWERT': 375,
#  'DAZU': 371,
#  'DIESER': 371,
#  'BRÜDER': 371,
#  'GESETZ': 369,
#  'HERZEN': 368,
#  'SÖHNE': 367,
#  'KNECHTE': 366,
#  'WERDET': 364,
#  'STIMME': 364,
#  'PROPHETEN': 363,
#  'BLUT': 362,
#  'ÄGYPTEN': 362,
#  'WÜSTE': 360,
#  'MEINER': 358,
#  'GEHE': 357,
#  'REDETE': 356,
#  'JOH': 355,
#  'REDEN': 354,
#  'GEKOMMEN': 353,
#  'SPR': 353,
#  'KANN': 350,
#  'JOSUA': 347,
#  'SAMT': 346,
#  'ZOG': 346,
#  'GAB': 344,
#  'ALLEM': 336,
#  'FÜRSTEN': 336,
#  'MEER': 335,
#  'SIEBEN': 335,
#  'JA': 334,
#  'JER': 334,
#  'WOLLEN': 332,
#  'GROSSE': 330,
#  'DARNACH': 330,
#  'GEWORDEN': 329,
#  'HÖREN': 329,
#  'OFFB': 328,
#  'SOLLTE': 324,
#  'WELT': 324,
#  'ANDERE': 323,
#  'GINGEN': 323,
#  'SELBST': 321,
#  'MEINES': 320,
#  'JES': 319,
#  'BRUDER': 318,
#  'GEREDET': 318,
#  'SEHR': 317,
#  'EUREN': 317,
#  'WELCHE': 316,
#  'WARUM': 314,
#  'GEBOTEN': 314,
#  'HIOB': 313,
#  'SAUL': 313,
#  'PETRUS': 312,
#  'HÜTTE': 311,
#  'GEWESEN': 311,
#  'WORTE': 311,
#  'KEINE': 310,
#  'DIESEN': 310,
#  'UNSER': 310,
#  'EINES': 310,
#  'ERDEN': 309,
#  'FLEISCH': 307,
#  'MUTTER': 307,
#  'OHNE': 307,
#  'ALLER': 305,
#  'GERECHTIGKEIT': 304,
#  '2.MOSE': 304,
#  'KÖN': 302,
#  'VATERS': 299,
#  'JEMAND': 298,
#  'APG': 298,
#  'DREI': 295,
#  'LIEBE': 295,
#  'STÄDTE': 295,
#  'GEMEINDE': 294,
#  'MATTH': 290,
#  'WOHNEN': 289,
#  'ALTAR': 288,
#  'TOCHTER': 287,
#  'BROT': 286,
#  'ZEBAOTH': 286,
#  '1.MOSE': 285,
#  'BABEL': 285,
#  'MORGEN': 284,
#  'GANZEN': 284,
#  'NEHMEN': 281,
#  'GEHT': 281,
#  'ANGESICHT': 280,
#  'JAKOB': 278,
#  'JUDA\x92S': 276,
#  'JEGLICHER': 275,
#  'STERBEN': 275,
#  'HALTEN': 275,
#  'DAVON': 273,
#  'APOSTELGESCHICHTE': 272,
#  'MENSCH': 272,
#  'ZOGEN': 272,
#  'GESCHRIEBEN': 272,
#  'VOLL': 271,
#  'ORT': 271,
#  'DAVIDS': 271,
#  'EWIGLICH': 269,
#  'REDE': 269,
#  'DIESEM': 269,
#  'SÜNDE': 267,
#  'GLEICH': 266,
#  'ENGEL': 266,
#  'GROSSEN': 265,
#  'STAND': 265,
#  'VÄTER': 265,
#  'HAUPT': 265,
#  'ALLEIN': 264,
#  'SANDTE': 264,
#  'JESU': 264,
#  'BERGE': 260,
#  'WEGE': 260,
#  'ZORN': 260,
#  'MUSS': 259,
#  'AARON': 259,
#  'LEVITEN': 259,
#  'HIESS': 258,
#  'JUDEN': 257,
#  'LEUTE': 256,
#  'MARKUS': 255,
#  'HEER': 254,
#  'WELCHER': 253,
#  'GLAUBEN': 253,
#  'GNADE': 252,
#  'BRANDOPFER': 252,
#  'VIELE': 252,
#  'STEHT': 251,
#  'IST\x92S': 250,
#  'WÜRDE': 249,
#  'DARAUF': 249,
#  'JAHR': 246,
#  'WOLLTE': 246,
#  'ETLICHE': 245,
#  'BRINGEN': 244,
#  'SALOMO': 243,
#  'GESEHEN': 241,
#  'BLEIBEN': 241,
#  'NACHT': 240,
#  'ENDE': 240,
#  'BUND': 237,
#  'VOLKS': 237,
#  'PHILISTER': 236,
#  'GOLD': 233,
#  'RECHTEN': 232,
#  'TUE': 232,
#  'WÄRE': 231,
#  'WEISS': 230,
#  'TAGES': 229,
#  'MÜSSEN': 229,
#  'CHRONIK': 229,
#  'DAHIN': 227,
#  'OB': 225,
#  'WEIL': 223,
#  'HESEK': 223,
#  'HEBRÄER': 222,
#  'HÖRTE': 221,
#  'WELCHEN': 221,
#  'HIER': 220,
#  'GEBOT': 219,
#  'ELLEN': 219,
#  'GOTTLOSEN': 218,
#  'ZEUGTE': 217,
#  'GEHÖRT': 217,
#  'ZIEHEN': 217,
#  'ALLERLEI': 214,
#  'HEUTE': 214,
#  'LUK': 214,
#  'OBERSTEN': 213,
#  'GUT': 212,
#  'ZWISCHEN': 212,
#  'SAGTE': 212,
#  'GANZ': 211,
#  'UNSRE': 211,
#  'KLEIDER': 210,
#  'REICH': 209,
#  'STEHEN': 209,
#  'FEINDE': 208,
#  'GESANDT': 208,
#  'TÖCHTER': 207,
#  'AB': 207,
#  'JÜNGER': 205,
#  'OFFENBARUNG': 204,
#  'SÜNDEN': 204,
#  'VIEH': 203,
#  'RECHTE': 203,
#  'SAM': 203,
#  'WEIBER': 202,
#  'ERSTEN': 202,
#  'ÜBEL': 202,
#  'HINAUF': 202,
#  'ÄGYPTENLAND': 201,
#  'GESCHEHEN': 200,
#  'MUND': 199,
#  'TÜR': 198,
#  'GROSS': 198,
#  'PHARAO': 198,
#  'DAMIT': 198,
#  'EHRE': 197,
#  'WELCHES': 196,
#  'SCHLUG': 196,
#  'LADE': 196,
#  'RIEF': 195,
#  'TOR': 194,
#  'HERRLICHKEIT': 193,
#  'LICHT': 192,
#  'ETWAS': 192,
#  'ÄLTESTEN': 192,
#  'WEISHEIT': 192,
#  'ABEND': 191,
#  'VÖLKER': 190,
#  'CHRISTUS': 190,
#  'GESCHAH': 189,
#  'MACHE': 189,
#  'TATEN': 189,
#  'HINAUS': 188,
#  'CHRISTI': 188,
#  'IHRES': 186,
#  'RICHTER': 186,
#  'WISSEN': 185,
#  'VIER': 184,
#  'LANG': 184,
#  'GESCHLECHT': 184,
#  'BRÜDERN': 184,
#  'SCHAFE': 182,
#  'LASST': 180,
#  'DIENEN': 180,
#  'WAGEN': 179,
#  'FELDE': 178,
#  'OPFER': 178,
#  'GEBOREN': 178,
#  'HERAUS': 177,
#  'FIEL': 177,
#  'SPRICH': 176,
#  'TIMOTHEUS': 175,
#  'OHREN': 175,
#  'ALT': 174,
#  'NUR': 174,
#  'TEIL': 174,
#  'MISSETAT': 174,
#  'TEMPEL': 174,
#  'EPHESER': 173,
#  'STÄTTE': 173,
#  'VÄTERN': 173,
#  'STUHL': 173,
#  'FÜHRTE': 172,
#  'WOHNUNG': 172,
#  'SONNE': 172,
#  'JOSEPH': 172,
#  'ZUVOR': 171,
#  'LIEGT': 171,
#  'NÄMLICH': 170,
#  'ABRAHAM': 170,
#  'FÜNF': 170,
#  '5.MOSE': 170,
#  'HESEKIEL': 169,
#  'DAN': 169,
#  'OPFERN': 169,
#  'HINEIN': 168,
#  'GUTES': 168,
#  'LANGE': 168,
#  'WAHRHEIT': 168,
#  'ZEICHEN': 167,
#  'GEFUNDEN': 167,
#  'STREIT': 167,
#  'FALLEN': 166,
#  'SILBER': 166,
#  'SAGT': 166,
#  'WEDER': 166,
#  'WERKE': 165,
#  'TOTEN': 165,
#  'KRAFT': 165,
#  'KOR': 165,
#  'PAULUS': 165,
#  'WEIBE': 164,
#  'BEIDE': 164,
#  'FRIEDEN': 164,
#  'STAMM': 164,
#  'DANN': 162,
#  'GEBOTE': 162,
#  'LEGTE': 161,
#  'FÜSSE': 161,
#  'SAHEN': 160,
#  'WEIN': 160,
#  'LAGER': 160,
#  'ZEHN': 159,
#  'DANIEL': 159,
#  'UNSERN': 158,
#  'UNGLÜCK': 158,
#  'KEINEN': 157,
#  'VERLASSEN': 156,
#  'TRINKEN': 156,
#  'ALL': 156,
#  'ÖL': 156,
#  'NIMM': 155,
#  'EPHRAIM': 155,
#  'SETZTE': 154,
#  'GENOMMEN': 154,
#  'GLEICHWIE': 154,
#  'WILLST': 153,
#  'SAMEN': 152,
#  'WEISE': 152,
#  'BARMHERZIGKEIT': 152,
#  'MITTERNACHT': 151,
#  'HAUSES': 150,
#  'UNSERS': 150,
#  'UNREIN': 150,
#  'SPRÜCHE': 149,
#  'GERECHTEN': 149,
#  'WERK': 149,
#  'LASSET': 148,
#  'BAUTE': 148,
#  'MACHTEN': 148,
#  'FERNE': 148,
#  'BÖSEN': 146,
#  'BRACHTE': 146,
#  'KOMME': 146,
#  'STÄDTEN': 146,
#  'GREUEL': 146,
#  'ZION': 146,
#  'SPEISE': 145,
#  'STARB': 145,
#  'DAHER': 145,
#  'ZWÖLF': 145,
#  'TRAT': 145,
#  'SPEISOPFER': 145,
#  'SEHET': 144,
#  'HEILIG': 144,
#  'JETZT': 144,
#  'STIFTS': 144,
#  'HÖRE': 143,
#  'JEGLICHEN': 142,
#  'JE': 142,
#  'EHE': 142,
#  'BENJAMIN': 142,
#  'RAT': 142,
#  'DARAN': 141,
#  '4.MOSE': 141,
#  'BRACHTEN': 140,
#  'FRÖHLICH': 139,
#  'KNECHTEN': 138,
#  'DURCHS': 138,
#  'SOLLTEN': 137,
#  'NAHMEN': 137,
#  'MUNDE': 137,
#  'EUREM': 137,
#  'LÄSST': 137,
#  'ARMEN': 137,
#  'TRAGEN': 136,
#  'GEFANGEN': 136,
#  'GROSSER': 136,
#  'WOHNTEN': 135,
#  'SOLCHE': 135,
#  'FEST': 135,
#  'VERDERBEN': 134,
#  'MARK': 134,
#  'HOCH': 133,
#  'GEFALLEN': 133,
#  'ER\x92S': 133,
#  'FRUCHT': 132,
#  'MITTAG': 132,
#  'GIBT': 132,
#  'BAUEN': 131,
#  'HÖRET': 131,
#  'JORDAN': 131,
#  'LANDES': 130,
#  'HÖRTEN': 130,
#  'GEBIRGE': 130,
#  'GELD': 130,
#  'HEISST': 129,
#  'UMHER': 129,
#  'MITTEN': 128,
#  'BERG': 128,
#  'KÖNNEN': 128,
#  'GÖTTER': 128,
#  'NÄCHSTEN': 128,
#  'GEBET': 128,
#  'WIDDER': 127,
#  'GEHET': 127,
#  'GUTEN': 126,
#  'LOT': 126,
#  'STANDEN': 126,
#  'UNSERM': 126,
#  'LUST': 126,
#  'FÜRCHTEN': 126,
#  'ABERMALS': 125,
#  'GÖTZEN': 125,
#  'NEBEN': 125,
#  'WANDELN': 125,
#  'WAHRLICH': 125,
#  'BÖSE': 124,
#  'GEWALT': 124,
#  'LEGEN': 124,
#  'FREUDE': 124,
#  'LEBT': 123,
#  'ERBE': 122,
#  'TOD': 122,
#  'WISSET': 122,
#  'FARREN': 122,
#  'STATT': 121,
#  'FÜRST': 121,
#  'AUFS': 121,
#  'SELIG': 121,
#  'LEIB': 121,
#  'SCHANDEN': 121,
#  'FINSTERNIS': 120,
#  'GESETZT': 120,
#  'SÖHNEN': 120,
#  'ICH\x92S': 120,
#  'DIESES': 120,
#  'BÖSES': 120,
#  'GRIMM': 120,
#  'JOAB': 120,
#  'C': 119,
#  'HINAB': 119,
#  'MITEINANDER': 119,
#  'FÜSSEN': 119,
#  'EURER': 118,
#  'WAHR': 118,
#  'FINDEN': 118,
#  'HÄTTE': 118,
#  'GILEAD': 118,
#  'WEISEN': 118,
#  'LOS': 118,
#  'GALATER': 117,
#  'FURCHT': 117,
#  'NAME': 117,
#  'ACH': 117,
#  'LIESSEN': 117,
#  'WELCHEM': 117,
#  'ZAHL': 117,
#  'HISKIA': 117,
#  'CHRISTO': 117,
#  'SEIEN': 116,
#  'ACKER': 116,
#  'IMMER': 116,
#  'NAHE': 116,
#  'JUNGEN': 116,
#  'GRENZE': 116,
#  '3.MOSE': 116,
#  'ERSTE': 115,
#  'TODES': 115,
#  'HÄNDEN': 115,
#  'KIND': 115,
#  'BESSER': 115,
#  'LIEGEN': 115,
#  'BLEIBT': 115,
#  'ERFAHREN': 115,
#  'REIN': 115,
#  'GABEN': 114,
#  'HOLZ': 114,
#  'MANASSE': 114,
#  'GROSSES': 113,
#  'GEBE': 113,
#  'SIEHT': 113,
#  'WIRD\x92S': 113,
#  'GÜTE': 113,
#  'SUCHEN': 113,
#  'WENIG': 112,
#  'LEHRE': 112,
#  'BUCH': 111,
#  'STREITEN': 111,
#  'JAKOBUS': 110,
#  'SCHWESTER': 110,
#  'ARBEIT': 110,
#  'SEITE': 110,
#  'HERAUF': 110,
#  'GEFÜHRT': 110,
#  'DARÜBER': 110,
#  'FÜHREN': 110,
#  'LIEBEN': 110,
#  'BLIEB': 109,
#  'PROPHET': 109,
#  'GERICHT': 109,
#  'GUTE': 109,
#  'REDET': 109,
#  'JESUM': 109,
#  'EMPFANGEN': 108,
#  'WESEN': 108,
#  'DERSELBEN': 108,
#  'DERER': 108,
#  'ENTGEGEN': 107,
#  'WOLLT': 107,
#  'FÜRCHTET': 107,
#  'KÖNIGREICH': 107,
#  'SÜNDOPFER': 107,
#  'WEH': 107,
#  'HÖHE': 106,
#  'MONATS': 106,
#  'HEILIGTUM': 106,
#  'ASSYRIEN': 105,
#  'WEITER': 105,
#  'MENGE': 105,
#  'TAUSEND': 105,
#  'SPRECHEN': 105,
#  'DRITTEN': 104,
#  'TAGEN': 104,
#  'GEBRACHT': 104,
#  'RICHTEN': 104,
#  'SACHE': 104,
#  'EITEL': 104,
#  'ERWÄHLT': 104,
#  'HIMMELS': 103,
#  'OBEN': 103,
#  'DIENER': 103,
#  'GÖTTERN': 103,
#  'VÖLKERN': 103,
#  'SETZEN': 102,
#  'ISAAK': 102,
#  'AMMON': 102,
#  'SACHARJA': 102,
#  'HERDE': 101,
#  'GESCHLECHTERN': 101,
#  'TUST': 101,
#  'MORGENS': 101,
#  'KOMM': 101,
#  'ERBTEIL': 101,
#  '1.CHRON': 101,
#  'UNTEREINANDER': 100,
#  'HÄUSER': 100,
#  'SITZEN': 100,
#  'JOS': 100,
#  'TIERE': 99,
#  'MONAT': 99,
#  'STEIN': 99,
#  'ZWANZIG': 99,
#  'GEFIEL': 99,
#  'ZEUGNIS': 99,
#  'TÖTEN': 99,
#  'SCHON': 99,
#  'HELFEN': 99,
#  'MENSCHENKIND': 99,
#  'PHILEMON': 99,
#  'GEBAR': 98,
#  'GESCHLAGEN': 98,
#  'FÜRCHTE': 98,
#  'MAGD': 98,
#  'MAUER': 98,
#  'HEILIGE': 98,
#  'JONATHAN': 98,
#  'ABSALOM': 98,
#  'STUNDE': 98,
#  'GNÄDIG': 97,
#  'FAND': 97,
#  'BEIDEN': 97,
#  'KEINER': 97,
#  'HOB': 97,
#  'TRATEN': 97,
#  'WUNDER': 97,
#  'RICHT': 97,
#  'SAMARIA': 97,
#  'BEGAB': 96,
#  'LEBENDIG': 96,
#  'SECHS': 96,
#  'FEINDEN': 96,
#  '9': 96,
#  'LEBENDIGEN': 95,
#  'TOT': 95,
#  'NIEDER': 95,
#  'UNRECHT': 95,
#  'GAR': 95,
#  'DEREN': 95,
#  'AUSSER': 95,
#  'O': 95,
#  'LASSE': 94,
#  'SIEBENTEN': 94,
#  'HEISSEN': 94,
#  'HINTER': 94,
#  'SEELEN': 94,
#  'OCHSEN': 94,
#  'HEIL': 94,
#  'ARM': 94,
#  'EWIGKEIT': 94,
#  'HOFFNUNG': 94,
#  'ZUSAMMEN': 93,
#  'BRINGT': 93,
#  'GEFÄNGNIS': 93,
#  'NOT': 93,
#  'RÖM': 93,
#  'VIERZIG': 92,
#  'ZUNGE': 92,
#  'WORTEN': 92,
#  'ELIA': 92,
#  'DIEWEIL': 91,
#  'FIELEN': 91,
#  'GIB': 91,
#  'GEFÄLLT': 91,
#  'WÜST': 90,
#  'WOHNTE': 90,
#  'BRUNNEN': 90,
#  'KLEID': 90,
#  'HUNDERT': 90,
#  'STEHE': 90,
#  'STEINE': 90,
#  'RUHE': 90,
#  'HÖRT': 90,
#  'FRIEDE': 90,
#  'ESRA': 90,
#  'TEUFEL': 90,
#  'THESSALONICHER': 89,
#  'FETT': 89,
#  'GERECHT': 89,
#  'SCHLUGEN': 89,
#  'ZEUGEN': 89,
#  'EINWOHNER': 89,
#  'MEISTER': 88,
#  'AMOS': 88,
#  'EURES': 88,
#  'MOABITER': 88,
#  'FRAGEN': 88,
#  'MICHA': 88,
#  'TÄGLICH': 88,
#  'DINGE': 88,
#  'SAULS': 88,
#  'NACHDEM': 87,
#  'LEUTEN': 87,
#  'BEGRABEN': 87,
#  'GESCHREI': 87,
#  'GESCHWOREN': 87,
#  'HAUFEN': 87,
#  'LEIDEN': 87,
#  'CHRON': 87,
#  'EVANGELIUM': 87,
#  'GEDENKE': 86,
#  'ÄGYPTER': 86,
#  'ESEL': 86,
#  'JEDERMANN': 86,
#  'IRGEND': 86,
#  'AMT': 86,
#  'JOEL': 86,
#  'PS': 86,
#  'WIEDERUM': 85,
#  'ANTLITZ': 85,
#  'FRÜCHTE': 85,
#  'PHARISÄER': 85,
#  'WOLLTEN': 84,
#  'KONNTE': 84,
#  'FAHREN': 84,
#  'MASS': 84,
#  'WANDTE': 84,
#  'GOLDENEN': 84,
#  'WEISST': 84,
#  'BOTEN': 84,
#  'FEIND': 84,
#  'GRUBE': 84,
#  'FRESSEN': 84,
#  'SABBAT': 84,
#  'HÖHEN': 84,
#  'BOSHEIT': 83,
#  'HERZENS': 83,
#  'WIND': 83,
#  'SCHLAGEN': 83,
#  'SOLANGE': 83,
#  'GESÜNDIGT': 83,
#  'TODE': 83,
#  'SELA': 83,
#  '12': 83,
#  'LAGERTEN': 83,
#  'GEGENÜBER': 82,
#  'HALTE': 82,
#  'ANTWORTETEN': 82,
#  'MÄCHTIG': 82,
#  'SCHADEN': 82,
#  'FELD': 81,
#  'SCHWER': 81,
#  'ÜBRIGEN': 81,
#  'SÄULEN': 81,
#  'SCHRIFT': 81,
#  'BERGEN': 81,
#  'UNSRER': 80,
#  'LAG': 80,
#  'STILL': 80,
#  'ERRETTEN': 80,
#  'LEHREN': 80,
#  '7': 80,
#  'BEREITET': 80,
#  'PRIESTERN': 80,
#  'NARREN': 80,
#  'SEHE': 79,
#  'LEBENS': 79,
#  'LEIBE': 79,
#  'GENUG': 79,
#  'RUFEN': 79,
#  'JAKOBS': 79,
#  'BALD': 79,
#  'WÜRDEN': 79,
#  'HAUPTMANN': 79,
#  'STÄRKE': 79,
#  'WOHNT': 79,
#  'GEBAUT': 79,
#  'RÜHMEN': 79,
#  'ALSBALD': 79,
#  'FREMDEN': 78,
#  'GENANNT': 78,
#  'HUREREI': 78,
#  'GESUND': 78,
#  'JENSEIT': 77,
#  'GEDACHTE': 77,
#  'BUNDES': 77,
#  'KANAAN': 77,
#  'AMORITER': 77,
#  'RINDER': 77,
#  'KONNTEN': 77,
#  'SASS': 77,
#  'HERZU': 77,
#  'NIMMT': 77,
#  'KÖNIGEN': 77,
#  'AARONS': 77,
#  'NEBUKADNEZAR': 77,
#  'DRITTE': 76,
#  'DIR\x92S': 76,
#  '10': 76,
#  'DESGLEICHEN': 76,
#  'ÜBRIG': 76,
#  'GEGANGEN': 76,
#  'MÄNNERN': 76,
#  'SPRECHT': 76,
#  'VERBORGEN': 76,
#  'LÖWEN': 76,
#  'FINDET': 75,
#  'FÜNFZIG': 75,
#  'DESSELBEN': 75,
#  'GESTORBEN': 75,
#  'HÄUPTER': 75,
#  'ROSSE': 75,
#  'ALLEZEIT': 75,
#  'JOSAPHAT': 75,
#  'JÜNGERN': 75,
#  'ZEITEN': 74,
#  'DARAUS': 74,
#  'SELBEN': 74,
#  'SONST': 74,
#  'GESEGNET': 74,
#  'HIRTEN': 74,
#  'GESICHT': 74,
#  'FÜHRTEN': 74,
#  'TORE': 74,
#  'GOLDENE': 74,
#  'GELEGT': 74,
#  'DIENST': 74,
#  'FREUEN': 74,
#  'ERRETTET': 74,
#  'AUGE': 74,
#  'HÄLT': 74,
#  'HEBR': 74,
#  'ANFANG': 73,
#  'NACHKOMMEN': 73,
#  'FANDEN': 73,
#  ...}
